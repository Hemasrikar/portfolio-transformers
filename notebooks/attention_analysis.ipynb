# %% [markdown]
# ## Attention Analysis of the Best Architecture
#
# In this notebook, we conduct sysmetic interpretability analysis of the best performing transformer variant.

# %%
import torch
import torch.nn as nn

import xgboost
import shap

# %% [markdown]
# ### Attention weight

# %% [markdown]
# ### Rollout Analysis

# %% [markdown]
# ### Gradient SHAP

# %% [markdown]
# ### Temporal Stability and Market Regime Analysis

# %% [markdown]
# ### Rolling Interpretability Stability
